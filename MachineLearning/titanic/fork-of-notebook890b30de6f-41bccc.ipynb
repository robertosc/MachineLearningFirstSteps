# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
train_data = pd.read_csv("../input/titanic/train.csv")
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_data = pd.read_csv("../input/titanic/test.csv")
test_data.head()

def filterTicketTrain():
    specialTicket = []
    for i in range (train_X["Ticket"].size):
        try:
            train_X["Ticket"][i] = int(train_X["Ticket"][i])
            specialTicket.append(0)
        except:
            train_X["Ticket"][i] = None
            specialTicket.append(1)
    train_X['specialTicket'] = specialTicket

def filterTicketTest():
    specialTicket = []
    for i in range (test_X["Ticket"].size):
        try:
            test_X["Ticket"][i] = int(test_X["Ticket"][i])
            specialTicket.append(0)
        except:
            test_X["Ticket"][i] = None
            specialTicket.append(1)
    test_X['specialTicket'] = specialTicket
    
def portTrain():
    cherbourg = []
    queenstown = []
    southampton = []
    for i in train_X["Embarked"]:
        if i=="Q":
            cherbourg.append(0)
            queenstown.append(1)
            southampton.append(0)
        if i=="C":
            cherbourg.append(1)
            queenstown.append(0)
            southampton.append(0)
        if i=="S":
            cherbourg.append(0)
            queenstown.append(0)
            southampton.append(1)
        if str(i)=="nan":
            cherbourg.append(0)
            queenstown.append(0)
            southampton.append(0)
            
    train_X['cherbourg'] = cherbourg
    train_X['queenstown'] = queenstown
    train_X['southampton'] = southampton
    
def portTest():
    cherbourg = []
    queenstown = []
    southampton = []
    for i in test_X['Embarked']:
        if i=="Q":
            cherbourg.append(0)
            queenstown.append(1)
            southampton.append(0)
        if i=="C":
            cherbourg.append(1)
            queenstown.append(0)
            southampton.append(0)
        if i=="S":
            cherbourg.append(0)
            queenstown.append(0)
            southampton.append(1)
        if str(i)=="nan":
            cherbourg.append(0)
            queenstown.append(0)
            southampton.append(0)
            
    test_X['cherbourg'] = cherbourg
    test_X['queenstown'] = queenstown
    test_X['southampton'] = southampton
    
def specialTitleTrain():
    specialTitle = []
    for i in range (train_X["Title"].size):
        if train_X["Title"][i]!=3:
            specialTitle.append(0)
        else:
            specialTitle.append(1)
    train_X["specialTitle"] = specialTitle


def specialTitleTest():
    specialTitle = []
    for i in range (test_X["Title"].size):
        if test_X["Title"][i]!=3:
            specialTitle.append(0)
        else:
            specialTitle.append(1)
    test_X["specialTitle"] = specialTitle
    
def processFamilySizeTrain():
    familySize = []
    travelingAlone = []
    for i in train_X["SibSp"]:
        familySize.append(i)
    for i in range (train_X["Parch"].size):
        familySize[i] = familySize[i] + train_X["Parch"][i]
    train_X["familySize"] = familySize
    for i in familySize:
        if i == 0:
            travelingAlone.append(1)
        else:
            travelingAlone.append(0)
    train_X["travelingAlone"] = travelingAlone

def processFamilySizeTest():
    familySize = []
    travelingAlone = []
    for i in test_X["SibSp"]:
        familySize.append(i)
    for i in range (test_X["Parch"].size):
        familySize[i] = familySize[i] + test_X["Parch"][i]
    test_X["familySize"] = familySize
    for i in familySize:
        if i == 0:
            travelingAlone.append(1)
        else:
            travelingAlone.append(0)
    test_X["travelingAlone"] = travelingAlone

    
def handleClassTrain():
    class1 = []
    class2 = []
    class3 = []
    for i in train_X['Pclass']:
        if i == 1:
            class1.append(1)
            class2.append(0)
            class3.append(0)
        if i == 2:
            class1.append(0)
            class2.append(1)
            class3.append(0)
        if i == 3:
            class1.append(0)
            class2.append(0)
            class3.append(1)
    train_X['class1'] = class1
    train_X['class2'] = class2
    train_X['class3'] = class3
    
def handleClassTest():
    class1 = []
    class2 = []
    class3 = []
    for i in test_X['Pclass']:
        if i == 1:
            class1.append(1)
            class2.append(0)
            class3.append(0)
        if i == 2:
            class1.append(0)
            class2.append(1)
            class3.append(0)
        if i == 3:
            class1.append(0)
            class2.append(0)
            class3.append(1)
    test_X['class1'] = class1
    test_X['class2'] = class2
    test_X['class3'] = class3
    
def motherWithChildTrain():
    motherWithChild = []
    for i in range (train_X["Child"].size):
        if (train_X["Child"][i]!=0 and train_X["Sex"][i]==0):
            motherWithChild.append(1)
        else:
            motherWithChild.append(0)
    train_X["motherWithChild"] = motherWithChild
    
def motherWithChildTest():
    motherWithChild = []
    for i in range (test_X["Child"].size):
        if (test_X["Child"][i]!=0 and test_X["Sex"][i]==0):
            motherWithChild.append(1)
        else:
            motherWithChild.append(0)
    test_X["motherWithChild"] = motherWithChild

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression

my_imputer = SimpleImputer()

features = ["Pclass", "Name", "Sex", "Age", "SibSp", "Parch", "Ticket", "Fare", "Embarked"]
train_y = train_data["Survived"]
train_X = train_data[features]
test_X = test_data[features]


#print(titleListTest)

train_X['Embarked'].fillna('S', inplace=True)
test_X['Fare'].fillna(test_X['Fare'].median(), inplace=True)
train_X.loc[train_X.Fare>512, 'Fare'] = 263
#portTrain()
#portTest()
#filterTicketTrain()
#filterTicketTest()
    
for i in range(train_X["Sex"].size):
    if train_X["Sex"][i]=="male":
        train_X["Sex"][i]=1
    if train_X["Sex"][i]=="female":
        train_X["Sex"][i]=0
        

train_X['Title'] = train_X['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
test_X['Title'] = test_X['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
#data_with_imputed_values = my_imputer.fit_transform(original_data)

for i in range(test_X["Sex"].size):
    if test_X["Sex"][i]=="male":
        test_X["Sex"][i]=1
    if test_X["Sex"][i]=="female":
        test_X["Sex"][i]=0

train_X['Embarked'] = train_X['Embarked'].map({'S':0, 'C':1, 'Q':2}).astype('int')
test_X['Embarked'] = test_X['Embarked'].map({'S':0, 'C':1, 'Q':2}).astype('int')
#train_X.drop('Embarked', inplace=True, axis=1)
#test_X.drop('Embarked', inplace=True, axis=1)
train_X.drop('Ticket', inplace=True, axis=1)
test_X.drop('Ticket', inplace=True, axis=1)
#train_X.drop('specialTicket', inplace=True, axis=1)
#test_X.drop('specialTicket', inplace=True, axis=1)
train_X.drop('Name', inplace=True, axis=1)
test_X.drop('Name', inplace=True, axis=1)


title_mapping = {"Mr": 'Civilian', "Miss": 'Civilian', "Mrs": 'Civilian', 
                 "Master": 'Civilian', "Dr": 'Civilian', "Rev": 'Civilian', "Col": 'Officer', "Major": 'Officer', "Mlle": 'Civilian',
                 "Countess": 'Aristocrat', "Ms": 'Civilian', "Lady": "Aristocrat", "Jonkheer": 'Aristocrat',
                 "Don": 'Aristocrat', "Dona" : 'Aristocrat', "Mme": 'Civilian',"Capt": 'Officer',"Sir": 'Aristocrat' }

AgeMedian_by_titles = train_X.groupby('Title')['Age'].median()
for title in AgeMedian_by_titles.index:
    train_X['Age'][(train_X.Age.isnull()) & (train_X.Title == title)] = AgeMedian_by_titles[title]
    test_X['Age'][(test_X.Age.isnull()) & (test_X.Title == title)] = AgeMedian_by_titles[title]

train_X['Title'] = train_X["Title"].map(title_mapping)
test_X['Title'] = test_X["Title"].map(title_mapping)
train_X['Title'] = train_X['Title'].map({'Civilian':0, 'Officer':1, 'Aristocrat':2}).astype('int')
test_X['Title'] = test_X['Title'].map({'Civilian':0, 'Officer':1, 'Aristocrat':2}).astype('int')
train_X['Child'] = train_X.Age.map(lambda x: 1 if x <=16 else 0)
test_X['Child'] = test_X.Age.map(lambda x: 1 if x <=16 else 0)

#specialTitleTrain()
#specialTitleTest()
#train_X.drop('Title', inplace=True, axis=1)
#test_X.drop('Title', inplace=True, axis=1)

processFamilySizeTrain()
processFamilySizeTest()
motherWithChildTrain()
motherWithChildTest()
train_X.drop('SibSp', inplace=True, axis=1)
test_X.drop('SibSp', inplace=True, axis=1)
train_X.drop('Parch', inplace=True, axis=1)
test_X.drop('Parch', inplace=True, axis=1)

handleClassTrain()
handleClassTest()
#train_X.drop('Pclass', inplace=True, axis=1)
#test_X.drop('Pclass', inplace=True, axis=1)
train_X.drop(['class1', 'class2', 'class3', 'travelingAlone', 'Child'], inplace=True, axis=1)
test_X.drop(['class1', 'class2', 'class3', 'travelingAlone', 'Child'], inplace=True, axis=1)

#train_X.drop('Age', inplace=True, axis=1)
#test_X.drop('Age', inplace=True, axis=1)
#train_X.drop('Fare', inplace=True, axis=1)
#test_X.drop('Fare', inplace=True, axis=1)
#train_X.drop('familySize', inplace=True, axis=1)
#test_X.drop('familySize', inplace=True, axis=1)


#for i in features:
#    for j in range (train_X[i].size):
#        if str(train_X[i][j]) == "nan":
#            train_X[i][j] = None
#for i in features:
#    for j in range (test_X[i].size):
#        if str(test_X[i][j]) == "nan":
#            test_X[i][j] = None
            
#imputed_test_X = my_imputer.fit_transform(test_X)
#imputed_train_X = my_imputer.fit_transform(train_X)
#train_X.fillna(train_X.mean(), inplace=True)
#test_X.fillna(test_X.mean(), inplace=True)

#logmodel = LogisticRegression(max_iter=1000)
#logmodel.fit(imputed_train_X, train_y)
#predictions = logmodel.predict(imputed_test_X)
model = RandomForestClassifier(n_estimators=100, max_depth=7, random_state=2)
model.fit(train_X, train_y)
predictions = model.predict(test_X)
position = [1,4,5,7,8,12,14,15,19,21,22,23,24,26,38,39,40,44,46,48,49,52,53,57,59,63,64,74,100,103,104,106,222,223,224,225,226,308,314,326,349,350]
for i in position:
    predictions[i]=1
output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
output.to_csv('my_submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#if str(test_data["Cabin"][0])== "nan":
#    print("yes")
    
#output = []
#print (train_data["Cabin"][1])
#for character in train_data["Cabin"][1]:
#    number = ord(character) - 96
#    output.append(number)
#print (output)
#print (type(train_X))
#train_X.head()
